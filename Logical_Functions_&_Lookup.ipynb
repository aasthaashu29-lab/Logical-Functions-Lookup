# %% [markdown]
# # **Logical Functions & Lookup**
#
# 1.rite a formula to check if the marks in cell are greater than or equal to 40. If yes, return , otherwise
# .
# B2 "Pass"
# "Fail
#
#     -->marks are in B2
#     =IF(B2>=40,"Pass","Fail")
#
#
# 2. company gives a bonus  if sales are above 40,000 and attendance is greater than or equal to 90%. Write a
# formula to calculate whether the employee will get a bonus or not
#
#     -->Assume:
# 	•	Sales in B2
# 	•	Attendance in C2
# =IF(AND(B2>40000,C2>=90),"Bonus","No Bonus")
#
#
# 3.rite a nested IF formula:
# If marks in are ≥ 90 → , ≥ 75 → , ≥ 50 → , otherwise . B2 "A" "B" "C" "Fail"
#
#     -->Criteria:
# 	•	≥ 90 → A
# 	•	≥ 75 → B
# 	•	≥ 50 → C
# 	•	Else → Fail
#
# Marks in B2
# =IF(B2>=90,"A",IF(B2>=75,"B",IF(B2>=50,"C","Fail")))
#
# 4.nd the Department of Employee ID = E103. Also explain which LOOKUP function is used and why?
#
#     -->Table range: A2:C5
# EmpID in column A, Department in column C
# =VLOOKUP("E103",A2:C5,3,FALSE)
# Why VLOOKUP?
# Because EmpID is in the first column and we want to fetch a value (Department) from the right side.
#
#
# 5.company has set the following commission structure for its sales team:If a salesperson achieves sales of ₹45,000, use the VLOOKUP function to determine the commission rate
# applicable.
#
#
#     -->Table range: A2:B5
# =VLOOKUP(45000,A2:B5,2,TRUE)
# Answer: 10% commission
#
# (Approximate match is used because commission slabs are ranges.)
#
#
# 6.Write an IF function to check whether an employee has Exceeded their allowed leave balance.
#
# If Leaves Taken > Allowed Leaves, display "Exceeded".
#
# Otherwise, display "OK".
#
#
#     -->Leaves Taken → B2
# 	•	Leaves Allowed → C2
# =IF(B2>C2,"Exceeded","OK")
#
#
# 7.Find the salary of EmpID = E105 using INDEX-MATCH Function.
#
#     -->Table:
# 	•	EmpID → A2:A5
# 	•	Salary → B2:B5
# =INDEX(B2:B5,MATCH("E105",A2:A5,0))
# Answer 72000
#
# 8.Use the XLOOKUP function to find the Department of the employee with Emp ID = E303.
#
#     -->EmpID column → A2:A5
# Department column → B2:B5
# =XLOOKUP("E303",A2:A5,B2:B5)
